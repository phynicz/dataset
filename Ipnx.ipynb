# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '.~lock.10000 Sales Records.csv#',
#  '10000 Sales Records.csv',
#  'Untitled.ipynb']

# %%
import pandas

# %%
df = pandas.read_csv("10000 Sales Records.csv")
df
# Out:
#                             Region                           Country  \
# 0               Sub-Saharan Africa                              Chad
# 1                           Europe                            Latvia
# 2     Middle East and North Africa                          Pakistan
# 3               Sub-Saharan Africa  Democratic Republic of the Congo
# 4                           Europe                    Czech Republic
# ...                            ...                               ...
# 9995                          Asia                              Laos
# 9996                        Europe                     Liechtenstein
# 9997            Sub-Saharan Africa  Democratic Republic of the Congo
# 9998            Sub-Saharan Africa                      South Africa
# 9999                          Asia                          Mongolia
#
#             Item Type Sales Channel Order Priority  Order Date   Order ID  \
# ...

# %%
total = df.iloc[: , 2:7]


total
# Out:
#             Item Type Sales Channel Order Priority  Order Date   Order ID
# 0     Office Supplies        Online              L   1/27/2011  292494523
# 1           Beverages        Online              C  12/28/2015  361825549
# 2          Vegetables       Offline              C   1/13/2011  141515767
# 3           Household        Online              C   9/11/2012  500364005
# 4           Beverages        Online              C  10/27/2015  127481591
# ...               ...           ...            ...         ...        ...
# 9995        Beverages        Online              H   7/15/2014  199342048
# 9996        Cosmetics        Online              C  10/27/2012  763044106
# 9997       Vegetables       Offline              M   2/14/2013  848579967
# 9998             Meat        Online              L   2/19/2017  298185956
# 9999           Snacks       Offline              M   4/12/2016  824410903
#
# [10000 rows x 5 columns]

# %%
total
# Out:
#             Item Type Sales Channel Order Priority  Order Date   Order ID
# 0     Office Supplies        Online              L   1/27/2011  292494523
# 1           Beverages        Online              C  12/28/2015  361825549
# 2          Vegetables       Offline              C   1/13/2011  141515767
# 3           Household        Online              C   9/11/2012  500364005
# 4           Beverages        Online              C  10/27/2015  127481591
# ...               ...           ...            ...         ...        ...
# 9995        Beverages        Online              H   7/15/2014  199342048
# 9996        Cosmetics        Online              C  10/27/2012  763044106
# 9997       Vegetables       Offline              M   2/14/2013  848579967
# 9998             Meat        Online              L   2/19/2017  298185956
# 9999           Snacks       Offline              M   4/12/2016  824410903
#
# [10000 rows x 5 columns]

# %%
total_table = total.pivot_table(index=['Item Type', 'Sales Channel'], values = 'Order ID', aggfunc='count')
total_table
# Out:
#                                Order ID
# Item Type       Sales Channel
# Baby Food       Offline             406
#                 Online              436
# Beverages       Offline             381
#                 Online              401
# Cereal          Offline             385
#                 Online              440
# Clothes         Offline             451
#                 Online              421
# Cosmetics       Offline             415
#                 Online              419
# Fruits          Offline             375
#                 Online              420
# Household       Offline             445
#                 Online              430
# Meat            Offline             401
#                 Online              397
# Office Supplies Offline             406
#                 Online              431
# Personal Care   Offline             433
#                 Online              455
# Snacks          Offline             406
#                 Online              410
# ...

# %%
total1= df.iloc[:,2:12]
total1
# Out:
#             Item Type Sales Channel Order Priority  Order Date   Order ID  \
# 0     Office Supplies        Online              L   1/27/2011  292494523
# 1           Beverages        Online              C  12/28/2015  361825549
# 2          Vegetables       Offline              C   1/13/2011  141515767
# 3           Household        Online              C   9/11/2012  500364005
# 4           Beverages        Online              C  10/27/2015  127481591
# ...               ...           ...            ...         ...        ...
# 9995        Beverages        Online              H   7/15/2014  199342048
# 9996        Cosmetics        Online              C  10/27/2012  763044106
# 9997       Vegetables       Offline              M   2/14/2013  848579967
# 9998             Meat        Online              L   2/19/2017  298185956
# 9999           Snacks       Offline              M   4/12/2016  824410903
#
#       Ship Date  Units Sold  Unit Price  Unit Cost  Total Revenue
# ...

# %%
total11= total1.drop(total1.columns[2:9],1)
total11
# Out:
#             Item Type Sales Channel  Total Revenue
# 0     Office Supplies        Online     2920025.64
# 1           Beverages        Online       51008.75
# 2          Vegetables       Offline     1003700.90
# 3           Household        Online     5134318.41
# 4           Beverages        Online      165647.95
# ...               ...           ...            ...
# 9995        Beverages        Online      407927.65
# 9996        Cosmetics        Online      245706.40
# 9997       Vegetables       Offline      388847.44
# 9998             Meat        Online     3672974.34
# 9999           Snacks       Offline       55081.38
#
# [10000 rows x 3 columns]

# %%
total_table1 = total11.pivot_table(index=['Item Type', 'Sales Channel'], values = 'Total Revenue', aggfunc='sum')
total_table1
# Out:
#                                Total Revenue
# Item Type       Sales Channel
# Baby Food       Offline         5.098684e+08
#                 Online          5.615432e+08
# Beverages       Offline         9.225893e+07
#                 Online          9.329126e+07
# Cereal          Offline         4.199672e+08
#                 Online          4.446709e+08
# Clothes         Offline         2.418966e+08
#                 Online          2.337282e+08
# Cosmetics       Offline         9.034712e+08
#                 Online          8.904872e+08
# Fruits          Offline         1.743829e+07
#                 Online          2.040345e+07
# Household       Offline         1.514671e+09
#                 Online          1.383485e+09
# Meat            Offline         8.129850e+08
#                 Online          8.684112e+08
# Office Supplies Offline         1.329366e+09
#                 Online          1.353791e+09
# Personal Care   Offline         1.734955e+08
# ...

# %%
total_table11= total_table1.loc['Office Supplies']
total_table11
# Out:
#                Total Revenue
# Sales Channel
# Offline         1.329366e+09
# Online          1.353791e+09

# %%
total11= total1.drop(total1.columns[2:9],1)
# Out:
#                             Region                           Country  \
# 0               Sub-Saharan Africa                              Chad
# 1                           Europe                            Latvia
# 2     Middle East and North Africa                          Pakistan
# 3               Sub-Saharan Africa  Democratic Republic of the Congo
# 4                           Europe                    Czech Republic
# ...                            ...                               ...
# 9995                          Asia                              Laos
# 9996                        Europe                     Liechtenstein
# 9997            Sub-Saharan Africa  Democratic Republic of the Congo
# 9998            Sub-Saharan Africa                      South Africa
# 9999                          Asia                          Mongolia
#
#             Item Type Sales Channel Order Priority  Order Date   Order ID  \
# ...

# %%
total_table2 = df.pivot_table(index=['Sales Channel'], values = 'Total Profit', aggfunc='sum')
total_table2
# Out:
#                Total Profit
# Sales Channel
# Offline        1.980902e+09
# Online         1.969991e+09

# %%
total_table3 = df.pivot_table(index=['Region','Item Type' ], values = 'Units Sold', aggfunc='sum')
total_table3
# Out:
#                                     Units Sold
# Region             Item Type
# Asia               Baby Food            665471
#                    Beverages            552183
#                    Cereal               606090
#                    Clothes              529194
#                    Cosmetics            595887
# ...                                        ...
# Sub-Saharan Africa Meat                1000175
#                    Office Supplies     1005652
#                    Personal Care       1063953
#                    Snacks              1114047
#                    Vegetables           981755
#
# [84 rows x 1 columns]

# %%
total33=total_table3.loc['Asia', 'Beverages']
total33
# Out:
# Units Sold    552183
# Name: (Asia, Beverages), dtype: int64

# %%
df_profit = df.drop(df.columns[2:13],1)
df_profit
# Out:
#                             Region                           Country  \
# 0               Sub-Saharan Africa                              Chad
# 1                           Europe                            Latvia
# 2     Middle East and North Africa                          Pakistan
# 3               Sub-Saharan Africa  Democratic Republic of the Congo
# 4                           Europe                    Czech Republic
# ...                            ...                               ...
# 9995                          Asia                              Laos
# 9996                        Europe                     Liechtenstein
# 9997            Sub-Saharan Africa  Democratic Republic of the Congo
# 9998            Sub-Saharan Africa                      South Africa
# 9999                          Asia                          Mongolia
#
#       Total Profit
# 0        566105.00
# 1         16834.50
# 2        411291.95
# 3       1273303.59
# 4         54669.06
# ...

# %%
total_table4 = df_profit.pivot_table(index=['Region'], values = 'Total Profit', aggfunc='sum')
total_table4
# Out:
#                                    Total Profit
# Region
# Asia                               5.874033e+08
# Australia and Oceania              3.240712e+08
# Central America and the Caribbean  4.033578e+08
# Europe                             1.027000e+09
# Middle East and North Africa       5.099239e+08
# North America                      9.949552e+07
# Sub-Saharan Africa                 9.996421e+08

# %%
max1=total_table4.loc[total_table4['Total Profit'].idxmax()]
max1
# Out:
# Total Profit    1.027000e+09
# Name: Europe, dtype: float64
